# %% [markdown]
# # raw

# %%
import pandas as pd
import numpy as np
import ast
import re
from collections import defaultdict

# %%
asian = pd.read_csv("asian.csv")
japan = pd.read_csv("japan.csv")
fastfood = pd.read_csv("fastfood.csv")
bars = pd.read_csv("bars.csv")
# Out:
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (9,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3,6,10,12,13,27,29,36,40,43,45,46,51,60,67,79,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# D:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3,6,10,42,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def formromantic(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is romantic, I can't wait to have a try!\n"
        else:
            z = "Your restaurant is not romantic, you can consider it if you want to improve your customers' experience!\n" 
            return z

# %%
x1 = list(map(formgroup,z["RestaurantsGoodForGroups"]))
x2 = list(map(formtrendy,z["trendy"]))
x3 = list(map(formreservation,z["RestaurantsReservations"]))
x4 = list(map(formtakeout,z["RestaurantsTakeOut"]))
x5 = list(map(formhipster,z["hipster"]))
x6 = list(map(formprice,z["RestaurantsPriceRange2"]))
x7 = list(map(formattire,z["RestaurantsAttire"]))
x8 = list(map(formclassy,z["classy"]))
x9 = list(map(formalcohol,z["Alcohol"]))
x10 = list(map(formtouristy,z["touristy"]))
x11 = list(map(formkids,z["GoodForKids"]))
x12 = list(map(formdelivery,z["RestaurantsDelivery"]))
x13 = list(map(formTV,z["HasTV"]))
x14 = list(map(formvalet,z["valet"]))
x15 = list(map(formromantic,z["romantic"]))

# %%
def mergeall(x):
    start = "Based on analysis over 40000 restaurants, We provide you some comments on your restaurant below:\n"
    x = x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x11 + x12 + x13 + x14 + x15
    end = "The more you do, the better your restaurant should be!\n Do what you are capable, remember, data are from others, but restaurant is yours!\n"
    if x == "":
        z = "Due to the lack of your restaurant's information\nOur system is not able to give you any advice now\nUpdate your restaurant's data to get insightful suggestions!"
    else:
        z = start + x + end
    return z

# %% [markdown]
# # fastfood

# %%
ID1 = list(fastfood["business_id"])

# %%
def getlatenight(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant open ultil latenight, that's a good idea, but as a fast food store, \nyou need to make sure that the latenight service is still good!\n\n"
        else:
            z = "Your restaurant will close at latenight, that's a good choice for a fast food store!\n\n" 
        return z

# %%
def getstreet(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is providing street parking, thanks for your considerance!\n\n"
        else:
            z = "Your restaurant doesn't provide street parking, you can choose to improve it to have higher ranking!\n\n" 
        return z

# %%
def getreservation(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant allows guest to make reservations, that's awesome!\n\n"
        else:
            z = "Your restaurant doesn't allow guest to make reservations, that will make you lose a lot of guests!\n\n" 
        return z

# %%
def getkids(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is good for kids, which will always make others uncomfortable, please take others' feelings into account!\n\n"
        else:
            z = "Your restaurant is not good for kids, that's a good choice!\n\n" 
        return z

# %%
def getbike(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant allows bike parking, bike riders all apologize that!\n\n"
        else:
            z = "Your restaurant doesn't allow bike parking, if you do it, you will attract more bike riders!\n\n" 
        return z

# %%
x1 = list(map(getlatenight,fastfood["latenight"]))
x2 = list(map(getstreet,fastfood["street"]))
x3 = list(map(getreservation,fastfood["RestaurantsReservations"]))
x4 = list(map(getkids,fastfood["GoodForKids"]))
x5 = list(map(getbike,fastfood["BikeParking"]))

# %%
m = pd.DataFrame({"x1":x1,"x2":x2,"x3":x3,"x4":x4,"x5":x5})

# %%
def mergeall(x):
    start = "Based on analysis over 30000 restaurants, We provide you some comments on your restaurant below:\n\n"
    x = x['x1'] + x['x2'] + x['x3'] + x['x4'] + x['x5']
    end = "The more you do, the better your restaurant should be!\nDo what you are capable, remember, data are from others, but restaurant is yours!\n\n"
    if x == "":
        z = "Due to the lack of your information\nOur system is not able to give you any advice now\nUpdate your data to get insightful suggestions!"
    else:
        z = start + x + end
    return z

# %%
fastfood11 = m.apply(mergeall,axis = 1)

# %%
fastfoodff = pd.DataFrame({"ID":ID1,"comments": fastfood11})

# %% [markdown]
# # bars

# %%
ID2 = list(bars["business_id"])

# %%
def getstreet(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is providing street parking, thanks for your considerance!\n\n"
        else:
            z = "Your restaurant doesn't provide street parking, you can choose to improve it to have higher ranking!\n\n" 
        return z

# %%
def getlatenight(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant open ultil latenight, that's a good idea, but as a fast food store, \nyou need to make sure that the latenight service is still good!\n\n"
        else:
            z = "Your restaurant will close at latenight, that's a good choice for a fast food store!\n\n" 
        return z

# %%
def getclassy(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is classy, people like it very much!\n\n"
        else:
            z = "Your restaurant is not classy, you can spend some money on your decoration!\n\n" 
        return z

# %%
def getkids(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is good for kids, which will always make others uncomfortable, please take others' feelings into account!\n\n"
        else:
            z = "Your restaurant is not good for kids, that's a good choice!\n\n" 
        return z

# %%
def getbike(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant allows bike parking, bike riders all apologize that!\n\n"
        else:
            z = "Your restaurant doesn't allow bike parking, if you do it, you will attract more bike riders!\n\n" 
        return z

# %%
x1 = list(map(getlatenight,bars["latenight"]))
x2 = list(map(getstreet,bars["street"]))
x3 = list(map(getclassy,bars["classy"]))
x4 = list(map(getkids,bars["GoodForKids"]))
x5 = list(map(getbike,bars["BikeParking"]))

# %%
m = pd.DataFrame({"x1":x1,"x2":x2,"x3":x3,"x4":x4,"x5":x5})

# %%
bars11 = m.apply(mergeall,axis = 1)

# %%
barsff = pd.DataFrame({"ID":ID2,"comments": bars11})

# %% [markdown]
# # japan

# %%
ID3 = list(japan["business_id"])

# %%
def getlatenight(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant open ultil latenight, that's a good idea, but as a fast food store, \nyou need to make sure that the latenight service is still good!\n\n"
        else:
            z = "Your restaurant will close at latenight, that's a good choice for a fast food store!\n\n" 
        return z

# %%
def gettable(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant provides table service, which is needed to pay much attention to, don't annoy your customers!\n\n"
        else:
            z = "Your restaurant doesn't provide table service, that's a wise choice!\n\n" 
        return z

# %%
def getgroup(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is good for groups, make it more private will improve the guest experience!\n\n"
        elif x == False:
            z = "Your restaurant is private enough, that's what your customers want!\n\n" 
        return z

# %%
def getTV(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant has TV, but TV may bother your guests, please try to trun it down or remove it!\n\n"
        else:
            z = "Your restaurant doesn't have TV, thank's for your consideration!\n\n" 
        return z

# %%
def getprice(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == 1:
            z = "Your price is good, keep your service and food!\n\n"
        elif x == 2:
            z = "Your price is kind of high, reducing it may help you out!\n\n" 
        elif x == 3:
            z = "Your price is kind of low, rise it may improve your ranking!\n\n"
        else:
            z = "Your price matchs your style, just keep it!\n\n"
        return z

# %%
x1 = list(map(getlatenight,japan["latenight"]))
x2 = list(map(gettable,japan["RestaurantsTableService"]))
x3 = list(map(getgroup,japan["RestaurantsGoodForGroups"]))
x4 = list(map(getTV,japan["HasTV"]))
x5 = list(map(getprice,japan["RestaurantsPriceRange2"]))

# %%
m = pd.DataFrame({"x1":x1,"x2":x2,"x3":x3,"x4":x4,"x5":x5})

# %%
japan11 = m.apply(mergeall,axis = 1)

# %%
japanff = pd.DataFrame({"ID":ID3,"comments": japan11})

# %% [markdown]
# # asian

# %%
ID4 = list(asian["business_id"])

# %%
def getcasual(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant doesn't have any restiction on customers' dressing, that's good!\n\n"
        else:
            z = "Your restaurant have some restriction on customers' dressing, that will make them uncomfortable!\n\n" 
        return z

# %%
def gettable(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant provides table service, which is needed to pay much attention to, don't annoy your customers!\n\n"
        else:
            z = "Your restaurant doesn't provide table service, that's a wise choice!\n\n" 
        return z

# %%
def getreservation(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant allows guest to make reservations, that's awesome!\n\n"
        else:
            z = "Your restaurant doesn't allow guest to make reservations, that will make you lose a lot of guests!\n\n" 
        return z

# %%
def getstreet(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant is providing street parking, thanks for your considerance!\n\n"
        else:
            z = "Your restaurant doesn't provide street parking, you can choose to improve it to have higher ranking!\n\n" 
        return z

# %%
def getdelivery(x):
    if pd.isnull(x) == True:
        return ""
    else:
        if x == True:
            z = "Your restaurant supports delivery, that's a wise choice!\n\n"
        else:
            z = "Your restaurant doesn't support delivery, which will make you lose much competitivenes, please try to improve it!\n\n" 
        return z

# %%
x1 = list(map(getcasual,asian["casual"]))
x2 = list(map(gettable,asian["RestaurantsTableService"]))
x3 = list(map(getreservation,asian["RestaurantsReservations"]))
x4 = list(map(getstreet,asian["street"]))
x5 = list(map(getdelivery,asian["RestaurantsDelivery"]))

# %%
m = pd.DataFrame({"x1":x1,"x2":x2,"x3":x3,"x4":x4,"x5":x5})

# %%
asian11 = m.apply(mergeall,axis = 1)

# %%
asianff = pd.DataFrame({"ID":ID4,"comments": asian11})

# %%
zz=pd.read_csv("id.txt",header=None)
zz=zz[0]

# %%
zzz = pd.concat([fastfoodff,barsff,japanff,asianff],ignore_index=True)

# %%
len(zzz)
# Out:
# 56527

# %%
mm = zzz.drop_duplicates(subset = ["ID"])

# %%
mm.to_csv("comments.csv",index=False,sep=',')
